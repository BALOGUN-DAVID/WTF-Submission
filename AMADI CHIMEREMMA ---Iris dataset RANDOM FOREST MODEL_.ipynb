# %% [markdown]
# # EXPLORING RANDOM FOREST MODEL USING IRIS DATASET

# %%
#IMPORTING LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_diabetes
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#assigning new variable name to the datasets
data_iris=load_iris()

# %%
dir(data_iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
data_iris = load_iris()
iris = pd.DataFrame(data = data_iris.data, columns = data_iris.feature_names)
iris["target"] = data_iris.target

# %%
#the iris dataset is made up of 150 rows and 5 rows
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#checking the target features or independent variaables
iris_feature = pd.DataFrame(data_iris.feature_name)
iris_feature
# Out:
#                    0
# 0  sepal length (cm)
# 1   sepal width (cm)
# 2  petal length (cm)
# 3   petal width (cm)

# %%
#checking the dependent variable
iris_target_names = pd.DataFrame(data_iris.target_names)
iris_target_names
# Out:
#             0
# 0      setosa
# 1  versicolor
# 2   virginica

# %%
#Gaining information from the data
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
#checking the numerical insights of the dataset
iris.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
#checking for duplicate values
iris[iris.duplicated()].sum()
# Out:
# sepal length (cm)    5.8
# sepal width (cm)     2.7
# petal length (cm)    5.1
# petal width (cm)     1.9
# target               2.0
# dtype: float64

# %%
#concatenating the dependent variable to the independent ones
iris['target'] = data_iris.target
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
#checking to see that the fearutres are balanced
iris['target'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: target, dtype: int64

# %% [markdown]
# ### Data Visualization

# %%
plt.title('species count')
sns.countplot(iris['target'])
plt.show()

# %%
X = iris.drop("target", axis = 1)
y = iris.target

# %%
#SPLITTING THE dataset into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3,random_state=44)

# %%
model = RandomForestClassifier (n_estimators = 25)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=25)

# %%
X_test
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 144                6.7               3.3                5.7               2.5
# 9                  4.9               3.1                1.5               0.1
# 79                 5.7               2.6                3.5               1.0
# 95                 5.7               3.0                4.2               1.2
# 104                6.5               3.0                5.8               2.2
# 47                 4.6               3.2                1.4               0.2
# 118                7.7               2.6                6.9               2.3
# 107                7.3               2.9                6.3               1.8
# 102                7.1               3.0                5.9               2.1
# 90                 5.5               2.6                4.4               1.2
# 17                 5.1               3.5                1.4               0.3
# ...

# %%
#checking if the target classes are balanced
y_test.value_counts()
# Out:
# 0    17
# 2    15
# 1    13
# Name: target, dtype: int64

# %%
#checking the accuracy of the model
model.score(X_test, y_test)
# Out:
# 0.9777777777777777

# %%
#checking how well our model can predict
y_predict = model.predict(X_test)
y_predict
# Out:
# array([2, 0, 1, 1, 2, 0, 2, 2, 2, 1, 0, 1, 0, 2, 0, 0, 2, 1, 0, 2, 1, 2,
#        2, 1, 2, 1, 0, 1, 0, 1, 0, 1, 1, 2, 0, 1, 0, 0, 2, 1, 0, 0, 2, 0,
#        0])

# %%
#confusion matrix
cm = confusion_matrix(y_test, y_predict)
cm
# Out:
# array([[17,  0,  0],
#        [ 0, 13,  0],
#        [ 0,  1, 14]], dtype=int64)

# %%
#visualizing the confusion matrix
sns.heatmap(cm, annot = True, fmt='.0f')
plt.ylabel("Actual")
plt.xlabel("Predicted")
plt.show()

# %%
 #classification  report
print(classification_report(y_test, y_predict ))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       0.93      1.00      0.96        13
#            2       1.00      0.93      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
